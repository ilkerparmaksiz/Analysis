# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms
import statistics as st
import os
import pickle
import glob
from scipy import stats
# %matplotlib inline
import random
import seaborn as sn
from IPython.display import display, HTML
from scipy.stats import norm
from scipy.optimize import curve_fit
from scipy.stats import chisquare

# import module
from tabulate import tabulate

display(HTML("<style>.container { width:80% !important; }</style>"))

font = {'family' : 'Ubuntu',
        'weight' : 'bold',
        'size'   : 20}

matplotlib.rc('font', **font)
# Out:
# <style>.container { width:80% !important; }</style>

# %%
gain = lambda Wb,R,NPE,e:Wb/(NPE*e*R)
NumofPE=lambda Wb,R,g,e:Wb/(R*g*e)

def PickleITDump(data,fileName):
    with open(fileName,'wb') as f:
        pickle.dump(data,f)
        
def PickleITRead(fileName):
    
    with open(fileName,'rb') as f:
        data=pickle.load(f)
    return data

def getValuesWithSource(files,weight):
    values={} 

    for i in files:
        count=0
        sources={}
        with open(i) as f:
            next(f)
            lines=f.readlines()
            for line in lines:
                splitline=line.split(",")
                if(splitline[0] in values.keys()):
                    if(splitline[1] in values[splitline[0]].keys()):
                        values[splitline[0]][splitline[1]]=np.append(values[splitline[0]][splitline[1]],round(int(splitline[2])/weight))
                    else:
                        sources[splitline[1]]=np.array(round(int(splitline[2])/weight))
                        values[splitline[0]][splitline[1]]=sources[splitline[1]]
                else:
                    sources={}
                    sources[splitline[1]]=np.array(round(int(splitline[2])/weight))
                    values[splitline[0]]=sources
        f.close()
        
    return values
### Photons

## point Source
Point_SolidAngle=lambda r,R:r**2/(4*(R**2))

## Disk Source
### Where A is Rs/d ,and B is Rd/d
Disk_SolidAngle=lambda A,B:(B**2/4)*(1-3/4*(A**2+B**2)+15/8*(1/3*(A**4+B**4)+(A*B)**2)-35/16*(1/4*(A**6+B**6)+3/2*(A*B)**2*(A**2+B**2)))

def getAll(Path):
    Files = glob.glob(Path,recursive=True)
    Values=getValuesWithSource(Files,1)
    return Values
    
def SmearIT(mean,percent):
    return np.random.normal(mean,mean*percent)

def CombineIT(data):
    entrie=-1
    for key in data:
        if(len(data[key])>entrie):
            entrie=len(data[key])
    
    valuearr=np.zeros(entrie)
  
    print(f"Number of Values is {entrie}")
    for key in data:
        count=0 
        for val in data[key]:
            valuearr[count]=valuearr[count]+val
            count=count+1
    return valuearr


def Fit(data,binss,fvalue=0,plot=False):
    # Define some test data which is close to Gaussian
    data=data[data>fvalue]
    if (plot):
        hist, bin_edges,__ = plt.hist(data,bins=binss,density=True)
    else:
        hist, bin_edges= np.histogram(data,bins=binss,density=True)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2

    # Define model function to be used to fit to the data above:
    def gauss(x, *p):
        A, mu, sigma = p
        return A*np.exp(-(x-mu)**2/(2.*sigma**2))

    # p0 is the initial guess for the fitting coefficients (A, mu and sigma above)
    p0 = [np.max(data), np.mean(data), np.std(data)]

    coeff, var_matrix = curve_fit(gauss, bin_centres, hist, p0=p0)

    # Get the fitted curve
    hist_fit = gauss(bin_centres, *coeff)
    if(plot):
        plt.plot(bin_centres, hist, label='Test data')
        plt.plot(bin_centres, hist_fit, label='Fitted data')
        plt.legend()
        plt.show()
        # Finally, lets get the fitting parameters, i.e. the mean and standard deviation:
        print ('Fitted mean = ', coeff[1])
        print ('Fitted standard deviation = ', coeff[2])

 
    return coeff

def ChiSquare(Expected,Observed):
        return np.sum((Observed-Expected)**2/Expected)


    
def SolidAngleNew(x_ie,y_ie,r_sphr,r_win,QE,mesh_trans,win_trans,ELGain):
    #x_ie x_coordinate of an ionization electron
    #y_ie y_coordinate of an ionization electron
    r_ie=np.sqrt(x_ie**2 + y_ie**2)

    #r_sphr #Cathode/Anode Distance, 14/36cm
    #r_win #Cathode/Anode Window Radius
    #QE
    #mesh_trans
    #win_trans

    theta = np.arctan((r_ie+r_win))/(r_sphr)
    d = np.sqrt((r_ie)**2 + (r_sphr)**2)
    r_win_eff = 0.5*(2*d*r_win*np.cos(theta))/(d+r_win*np.sin(theta))
    a_win = np.pi*r_win*r_win_eff
    SA = a_win/(4*np.pi*(d)**2)

    EL = np.random.poisson(ELGain)

    detected_pe = np.sum(EL*SA)*QE*mesh_trans*win_trans
    
    return detected_pe

def getElectrons(r_sphr,r_win,QE,mesh_trans,win_trans,ELGain):
    data=PickleITRead("Electrons.p")
    PEs=np.array([])
    for event in data:
        solid=SolidAngleNew((data[event][0]/10),(data[event][1]/10),r_sphr,r_win,QE,mesh_trans,win_trans,ELGain)
        PEs=np.append(PEs,solid)
    return PEs


def ObtainValues(values):
    ### Applying Constants
        
    Results={}
    E1000ms=getAll(values["Path"])
    Alphas=E1000ms['All_e']["Po210"]
    Betas=E1000ms['All_e']["Bi210"]
    ## Solid Angle Calculations
    if(values["point"]):
        SolidAngle_AnodeWindowAlphas=Alphas*Point_SolidAngle(values["AnodeWindowRadius"],values["AnodePMTDistance"])*values["ELGain"]*values["AnodeQE"]*values["AnodeMeshLoss"]*values["TrasmissionLoss"]
        SolidAngle_CathodeWindowAlphas=Alphas*Point_SolidAngle(values["CathodeWindowRadius"],values["CathodePMTDistance"])*values["ELGain"]*values["CathodeQE"]*values["CathodeMeshLoss"]*values["TrasmissionLoss"]
    else:
        SolidAngle_AnodeWindowAlphas=getElectrons(values["AnodePMTDistance"],values["AnodeWindowRadius"],values["AnodeQE"],values["AnodeMeshLoss"],values["TrasmissionLoss"],values["ELGain"])
        SolidAngle_CathodeWindowAlphas=getElectrons(values["CathodePMTDistance"],values["CathodeWindowRadius"],values["CathodeQE"],values["CathodeMeshLoss"],values["TrasmissionLoss"],values["ELGain"])
    
        
        
    ## Solid Angle Calculations
    #SolidAngle_AnodeWindowAlphas=Alphas*Point_SolidAngle(values["AnodeWindowRadius"],values["AnodePMTDistance"])*values["ELGain"]*values["AnodeQE"]*values["AnodeMeshLoss"]*values["TrasmissionLoss"]
    #SolidAngle_CathodeWindowAlphas=Alphas*Point_SolidAngle(values["CathodeWindowRadius"],values["CathodePMTDistance"])*values["ELGain"]*values["CathodeQE"]*values["CathodeMeshLoss"]*values["TrasmissionLoss"]
    Results["SolidAngle_CathodeWindowBetas"]=Betas*Point_SolidAngle(values["CathodeWindowRadius"],values["CathodePMTDistance"])*values["ELGain"]*values["CathodeQE"]*values["CathodeMeshLoss"]*values["TrasmissionLoss"]
    Results["SolidAngle_AnodeWindowBetas"]=Betas*Point_SolidAngle(values["AnodeWindowRadius"],values["AnodePMTDistance"])*values["ELGain"]*values["AnodeQE"]*values["AnodeMeshLoss"]*values["TrasmissionLoss"]
    #### Adding Smearing 
   

    if(values["isSmearIT"]):
        Results["SolidAngle_CathodeWindowAlphas"]=SmearIT(SolidAngle_CathodeWindowAlphas,values["Smearing"])
        Results["SolidAngle_AnodeWindowAlphas"]=SmearIT(SolidAngle_AnodeWindowAlphas,values["Smearing"])
    else:
        Results["SolidAngle_CathodeWindowAlphas"]=SolidAngle_CathodeWindowAlphas
        Results["SolidAngle_AnodeWindowAlphas"]=SolidAngle_AnodeWindowAlphas

    
    Cathode_Alphas=E1000ms["Cathode_PHOTOCATHODE"]["Po210"]*values["CathodeQE"]
    Anode_Alphas=E1000ms["Anode_PHOTOCATHODE"]["Po210"]*values["AnodeQE"]
    Results["CathodeBetaPEs_G4"]=E1000ms["Cathode_PHOTOCATHODE"]["Bi210"]*values["CathodeQE"]
    Results["AnodeBetaPEs_G4"]=E1000ms["Anode_PHOTOCATHODE"]["Bi210"]*values["AnodeQE"]
    ## G4
    if(not values["Updated"]):
        Cathode_Alphas=Cathode_Alphas*values["CathodeMeshLoss"]
        Anode_Alphas=Anode_Alphas*values["AnodeMeshLoss"]
        Results["CathodeBetaPEs_G4"]=Results["CathodeBetaPEs_G4"]*values["CathodeMeshLoss"]
        Results["AnodeBetaPEs_G4"]=Results["AnodeBetaPEs_G4"]*values["AnodeMeshLoss"]
        
    if(values["TransLossOnG4"]):
        Cathode_Alphas=Cathode_Alphas*values["TrasmissionLoss"]
        Anode_Alphas=Anode_Alphas*values["TrasmissionLoss"]
        Results["CathodeBetaPEs_G4"]=Results["CathodeBetaPEs_G4"]*values["TrasmissionLoss"]
        Results["AnodeBetaPEs_G4"]=Results["AnodeBetaPEs_G4"]*values["TrasmissionLoss"]
        
            ##### Adding Smearing 
    if(values["isSmearIT"]):
        Results["CathodeAlphaPEs_G4"]=SmearIT(Cathode_Alphas,values["Smearing"])
        Results["AnodeAlphaPEs_G4"]=SmearIT(Anode_Alphas,values["Smearing"])
    else:
        Results["CathodeAlphaPEs_G4"]=Cathode_Alphas
        Results["AnodeAlphaPEs_G4"]=Anode_Alphas
    
    return Results


## Algoritim for minimizing
def ObtainBestQE(QEs,Anode,Cathode,Const,plot=False):
    Data_Anode=Fit(Anode,np.linspace(0,15000,60),3000,plot)
    Data_Cathode=Fit(Cathode,np.linspace(0,3000,60),1500,plot)
    values={}
    for qe in QEs:
        Const["AnodeQE"]=qe
        Const["CathodeQE"]=qe
        Result=ObtainValues(Const)
        SimG4_Anode=Fit(Result["AnodeAlphaPEs_G4"],np.linspace(0,20000,60),3000,plot)
        SimG4_Cathode=Fit(Result["CathodeAlphaPEs_G4"],np.linspace(0,5000,60),1200,plot)
        CathodeError=abs((SimG4_Cathode[1]-Data_Cathode[1])/Data_Cathode[1])
        AnodeError=abs((SimG4_Anode[1]-Data_Anode[1])/Data_Anode[1])

        #ChiCathode=ChiSquare(Data_Cathode[1],SimG4_Cathode[1])
        #ChiAnode=ChiSquare(Data_Anode[1],SimG4_Anode[1])
    
        ChiCathode=ChiSquare(CathodeError,0)
        ChiAnode=ChiSquare(AnodeError,0)
        arr=np.array([ChiAnode,ChiCathode])
        Chi=ChiSquare(arr,0)
        values[np.round(Chi,3)]=round(qe,3)
        print(f"QE is {qe} and  ChiAnode --> {ChiAnode} and ChiCathode --> {ChiCathode} Chi --> {Chi}" )
    
    keys=np.array(list(values.keys()))
    minkey=np.min(keys)
    Const["AnodeQE"]=values[minkey]
    Const["CathodeQE"]=values[minkey]
    print(f"Best QE is {values[minkey]} with minimum value of {minkey}")

# %%
### Gains ###
IlkersGains=[3822280,2545331]
#IlkersGains=NicksGains=[3.4e6,2.2e6]

# %%
## Obtain the Data
Area=PickleITRead("Area.p")

#Area=PickleITRead("AreaWithMinPulse.p")
## Obtain Sim Data
#SimData=PickleITRead("Sim.p")

# %%
##### Needle Only
#S2_NeedleOnlyPath="/media/ilker/Ilker/SimResults/Sep_28_2022/NeedleOnly/counts_1000/Photon_*.txt"
#S2_NeedleOnlyFiles = glob.glob(S2_NeedleOnlyPath,recursive=True)
#S2_NeedleOnly=getValuesWithSource(S2_NeedleOnlyFiles,1)




#S2_NeedleOnlyInfoPath="/media/ilker/Ilker/SimResults/Sep_28_2022/NeedleOnly/counts_1000/Extra_*.txt"
#S2_infoNeedleOnlyFiles = glob.glob(S2_NeedleOnlyInfoPath,recursive=True)
#S2_info_NeedleOnly=getValuesWithSource(S2_infoNeedleOnlyFiles,1)


### With Needle + Collimator
#S2_NeedleCollimPath="/media/ilker/Ilker/SimResults/Sep_28_2022/Collimator/counts/Photon_*.txt"
#S2_NeedleCollimFiles = glob.glob(S2_NeedleCollimPath,recursive=True)
#S2_NeedleCollim=getValuesWithSource(S2_NeedleCollimFiles,1)


#S2_NeedleCollimInfoPath="/media/ilker/Ilker/SimResults/Sep_28_2022/Collimator/counts/Extra_*.txt"
#S2_NeedleCollimInfoFiles = glob.glob(S2_NeedleCollimInfoPath,recursive=True)
#S2_info_NeedleCollim=getValuesWithSource(S2_NeedleCollimInfoFiles,1)

# %%
#values={"Needle":S2_NeedleOnly,
#        "NeedleInfo":S2_info_NeedleOnly,
#        "NeedleColim":S2_NeedleCollim,
#        "NeedleColimInfo":S2_info_NeedleCollim}
#PickleITDump(values,"Sim.p")

# %%
## Gain Calculations

### PMT Gains Ilker
Day1_PMT1_GainIL=NumofPE(Area["Day1_Ch1Area_PMT1"],50,IlkersGains[0],1.62e-19)
Day1_PMT3_GainIL=NumofPE(Area["Day1_Ch2Area_PMT3"],50,IlkersGains[1],1.62e-19)
Day2_PMT1_GainIL=NumofPE(Area["Day2_Ch1Area_PMT1"],50,IlkersGains[0],1.62e-19)
Day2_PMT3_GainIL=NumofPE(Area["Day2_Ch2Area_PMT3"],50,IlkersGains[1],1.62e-19)

### PMT Gains Nick
#Day1_PMT1_GainNk=NumofPE(Area["Day1_Ch1Area_PMT1"],50,NicksGains[0],1.62e-19)
#Day1_PMT3_GainNk=NumofPE(Area["Day1_Ch2Area_PMT3"],50,NicksGains[1],1.62e-19)
#Day2_PMT1_GainNk=NumofPE(Area["Day2_Ch1Area_PMT1"],50,NicksGains[0],1.62e-19)
#Day2_PMT3_GainNk=NumofPE(Area["Day2_Ch2Area_PMT3"],50,NicksGains[1],1.62e-19)

# %%
### Laptop
#path="/home/ilker/Desktop/SimResults/"
### From_External Drive
path="/media/ilker/Ilker/SimResults/"
#E1000ms=getAll(path+"Mar_9_2023/OldGeo/counts/Extra_*.txt")
E1000ms=getAll(path+"Mar9_2023/Test/counts/Extra_*.txt")
#E1000ms=getAll(path+"Dec_16_2022/S2500/counts/Extra_*.txt")
#Electrons_1000ms=getAll(path+"Dec_21_2022/counts/Extra_*.txt")
Electrons_1000ms=E1000ms

# %%
#L170nm=getAll("/media/ilker/Ilker/SimResults/Mar10_2023/Updated_500/counts/Extra_*.txt")
#L172nm=getAll("/media/ilker/Ilker/SimResults/Apr8_2023/172nm/counts/Extra_*.txt")

# %% [raw]
# plt.figure(figsize=(3,3),dpi=300)
# plt.hist(L170nm["Total_Produced_Photons"]["None"],bins=100,density=True,stacked=True)
# plt.hist(L172nm["Total_Produced_Photons"]["None"],bins=100,density=True,stacked=True)
# plt.show()

# %%
Constants_172nm={
    "Disc":"Updated_Geometry_172nm",
    "Path":"Apr10_2023/172nm_Gaussian_NoAbs_PMT35/counts/Extra_*.txt",
    "AnodeQE":0.097,
    "CathodeQE":0.097,
    "Smearing":(7.17/(2.355*100)), 
    "ELGain":647.5,
    "AnodeMeshLoss":0.91,
    "CathodeMeshLoss":0.85,
    "TrasmissionLoss":0.87,
    "CathodeWindowRadius":(16.58/10)/2,
    "AnodeWindowRadius":(16.22/10)/2,
    "AnodePMTDistance" :14,
    "CathodePMTDistance" :35,
    "Updated":True,
    "TransLossOnG4":True,
    "point":True,
    "isSmearIT":False

}

# %%
Constants_170nm={
    "Disc":"Updated_Geometry_170nm_Gaussian",
    "Path":"Apr10_2023/170nm_Gaussian_NoAbs_PMT35/counts/Extra_*.txt",
    "AnodeQE":(0.097*0.994261119),
    "CathodeQE":(0.097*0.994261119),
    "Smearing":(7.17/(2.355*100)), 
    "ELGain":647.5,
    "AnodeMeshLoss":0.91,
    "CathodeMeshLoss":0.85,
    "TrasmissionLoss":0.86,
    "CathodeWindowRadius":(16.58/10)/2,
    "AnodeWindowRadius":(16.22/10)/2,
    "AnodePMTDistance" :14,
    "CathodePMTDistance" :35,
    "Updated":True,
    "TransLossOnG4":True,
    "point":True,
    "isSmearIT":False

}

# %%
QEs=np.arange(0.09,0.13,0.001)

# %% [markdown]
# #Get Best QE for both PMTs
# ObtainBestQE(QEs,Day2_PMT1_GainIL,Day2_PMT3_GainIL,Constants_172nm)
# ObtainBestQE(QEs,Day2_PMT1_GainIL,Day2_PMT3_GainIL,Constants_170nm)

# %%
Result_172=ObtainValues(Constants_172nm)
Result_170=ObtainValues(Constants_170nm)

# %% [raw]
# ### Applying Constants
#
#
# ## Solid Angle Calculations
# SolidAngle_AnodeWindowAlphas=Alphas*Point_SolidAngle(AnodeWindowRadius,14)*ELGain*AnodeQE*AnodeScale
# SolidAngle_CathodeWindowAlphas=Alphas*Point_SolidAngle(CathodeWindowRadius,36)*ELGain*CathodeQE*CathodeScale
# SolidAngle_CathodeWindowBetas=Betas*Point_SolidAngle(CathodeWindowRadius,36)*ELGain*CathodeQE*CathodeScale
# SolidAngle_AnodeWindowBetas=Betas*Point_SolidAngle(AnodeWindowRadius,14)*ELGain*AnodeQE*AnodeScale
# #### Adding Smearing
# CathodeAlphaPEs_SolidAngle=SmearIT(SolidAngle_CathodeWindowAlphas,Smearing)
# AnodeAlphaPEs_SolidAngle=SmearIT(SolidAngle_AnodeWindowAlphas,Smearing)
#
# ## G4
# CathodeBetaPEs_G4=E1000ms["Cathode_PHOTOCATHODE"]["Bi210"]*CathodeQE*CathodeScale
# AnodeBetaPEs_G4=E1000ms["Anode_PHOTOCATHODE"]["Bi210"]*AnodeQE*AnodeScale
#
# ##### Adding Smearing
# CathodeAlphaPEs_G4=SmearIT(E1000ms["Cathode_PHOTOCATHODE"]["Po210"]*CathodeQE*CathodeScale,Smearing)
# AnodeAlphaPEs_G4=SmearIT(E1000ms["Anode_PHOTOCATHODE"]["Po210"]*AnodeQE*AnodeScale,Smearing)
#
#
#
# ## G4
# #CathodeBetaPEs_G4=E1000ms["S2_PHOTOCATHODE"]["Bi210"]*CathodeQE*CathodeScale
# #AnodeBetaPEs_G4=E1000ms["S1_PHOTOCATHODE"]["Bi210"]*AnodeQE*AnodeScale
#
# ##### Adding Smearing
# #CathodeAlphaPEs_G4=SmearIT(E1000ms["S2_PHOTOCATHODE"]["Po210"]*CathodeQE*CathodeScale,Smearing)
# #AnodeAlphaPEs_G4=SmearIT(E1000ms["S1_PHOTOCATHODE"]["Po210"]*AnodeQE*AnodeScale,Smearing)
# print(np.mean(E1000ms["Cathode_PHOTOCATHODE"]["Po210"]*CathodeScale))

# %%
SimG4_Cathode_172=Fit(Result_172["CathodeAlphaPEs_G4"],np.linspace(0,3000,60),1200,False)
SimG4_Cathode_170=Fit(Result_170["CathodeAlphaPEs_G4"],np.linspace(0,3000,60),1200,False)

CathodeDiff=abs(SimG4_Cathode_172[1]-SimG4_Cathode_170[1])/((SimG4_Cathode_172[1]+SimG4_Cathode_170[1])/2)

# %%
SimG4_Anode_172=Fit(Result_172["AnodeAlphaPEs_G4"],np.linspace(0,15000,60),3000,False)
SimG4_Anode_170=Fit(Result_170["AnodeAlphaPEs_G4"],np.linspace(0,15000,60),3000,False)
AnodeDif=abs(SimG4_Anode_172[1]-SimG4_Anode_170[1])/((SimG4_Anode_170[1]+SimG4_Anode_172[1])/2)

# %%
print("Anode Error")
AnodeError=np.sqrt((SimG4_Anode_172[2]/SimG4_Anode_172[1])**2+(SimG4_Anode_170[2]/SimG4_Anode_170[1])**2)
print(f"Difference is {round(AnodeDif*100,1)}")
print(f"Relative Error  is {round(AnodeError*AnodeDif*100,1)}")
print("\nCathode Error")
CathodeError=np.sqrt((SimG4_Cathode_172[2]/SimG4_Cathode_172[1])**2+(SimG4_Cathode_170[2]/SimG4_Cathode_170[1])**2)
print(f"Difference is {round(CathodeDiff*100,2)}")
print(f"Relative Error  is {round(CathodeError*CathodeDiff*100,2)}")
# Out:
# Anode Error
# Difference is 1.8
# Relative Error  is 0.1
#
# Cathode Error
# Difference is 1.44
# Relative Error  is 0.1

# %%
### Data Comp. Day2 PMT3 Comparison

binss=np.linspace(0,2500,50)
plt.figure(figsize=(12,8),dpi=300)
plt.title("Cathode Window S2 Light Comparison_")
plt.ylabel("Number of Events")
plt.xlabel("NPE")


plt.hist(Day2_PMT3_GainIL,bins=binss,density=True,stacked=True,label="After Purification",color="b",alpha=0.3)
plt.hist(Result_172["CathodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) 172nm",alpha=0.3)
plt.hist(Result_170["CathodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) 170nm",alpha=0.3)

#plt.hist(Result["CathodeBetaPEs_G4"],bins=binss ,density=True,stacked=True,label="Bi210 (GEANT4) 172nm",alpha=0.3)
#plt.hist(Result["SolidAngle_CathodeWindowAlphas"],bins=binss ,density=True,stacked=True,label="Po210 (Solid)  172nm",alpha=0.3)


#plt.hist(ResultWithNoTransmission["CathodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) 170nm",alpha=0.3)
#plt.hist(ResultWithNoTransmission["CathodeBetaPEs_G4"],bins=binss ,density=True,stacked=True,label="Bi210 (GEANT4) 170nm",alpha=0.3)
#plt.hist(ResultWithNoTransmission["SolidAngle_CathodeWindowAlphas"],bins=binss ,density=True,stacked=True,label="Po210 (Solid)  170nm",alpha=0.3)

#plt.hist(Result["SolidAngle_CathodeWindowAlphas"],bins=binss,density=True,stacked=True,label="Po210 (Solid Angle)",color="y",alpha=0.3)
#plt.hist(Result["SolidAngle_CathodeWindowBetas"],bins=binss,density=True,stacked=True,label="Bi210 (Solid Angle)",color="k",alpha=0.3)
plt.legend()
#plt.savefig("/home/ilker/Desktop/CRAB_Pictures/PMT3_S2_Light_Yield_Comp.jpeg")

plt.show()

# %% [raw]
# #### Condition for Alphas obtained from simulation above ####
#
# PMT3_BeforePurifaction_Alphas_DFiltered=Day1_PMT3_GainIL[np.where(np.logical_and(Day1_PMT3_GainIL>=1000,Day1_PMT3_GainIL<=1500))]
# PMT3_AfterPurifaction_Alphas_DFiltered=Day2_PMT3_GainIL[Day2_PMT3_GainIL>MaxbetaPECathode]
#
# alpha_CathodeWindow_G4Filtered=alpha_CathodeWindow[np.where(np.logical_and(alpha_CathodeWindow>=1000,alpha_CathodeWindow<=1500))]
# SolidAngle_AlphaCathodeWindow_G4Filtered=SmearIT(SolidAngle_CathodeWindowAlphas[np.where(np.logical_and(SolidAngle_CathodeWindowAlphas>=1000,SolidAngle_CathodeWindowAlphas<=1500))],0.025)
# SolidAngle_AlphaCathodeWindow_G4Filtered=SolidAngle_AlphaCathodeWindow_G4Filtered[SolidAngle_AlphaCathodeWindow_G4Filtered>np.max(SolidAngle_CathodeWindowBetas)]
# print(f"Mean --> {np.mean(PMT3_BeforePurifaction_Alphas_DFiltered)} and STD -->{np.std(PMT3_BeforePurifaction_Alphas_DFiltered)}")
# print(f"Mean --> {np.mean(PMT3_AfterPurifaction_Alphas_DFiltered)} and STD -->{np.std(PMT3_AfterPurifaction_Alphas_DFiltered)}")

# %% [raw]
# #### Condition for Alphas obtained from simulation above ####
# PMT3_BeforePurifaction_Alphas_DFiltered=Day1_PMT3_GainIL[Day1_PMT3_GainIL>MaxbetaPECathode]
# PMT3_AfterPurifaction_Alphas_DFiltered=Day2_PMT3_GainIL[Day2_PMT3_GainIL>MaxbetaPECathode]
#
# alpha_CathodeWindow_G4Filtered=CathodeAlphaPEs_G4[CathodeAlphaPEs_G4>MaxbetaPECathode]
# SolidAngle_AlphaCathodeWindow_G4Filtered=SolidAngle_CathodeWindowAlphas[SolidAngle_CathodeWindowAlphas>MaxbetaPECathode]
# print(f"Mean --> {np.mean(PMT3_BeforePurifaction_Alphas_DFiltered)} and STD -->{np.std(PMT3_BeforePurifaction_Alphas_DFiltered)/np.sqrt(len(PMT3_BeforePurifaction_Alphas_DFiltered))}")
# print(f"Mean --> {np.mean(PMT3_AfterPurifaction_Alphas_DFiltered)} and STD -->{np.std(PMT3_AfterPurifaction_Alphas_DFiltered)/np.sqrt(len(PMT3_AfterPurifaction_Alphas_DFiltered))}")

# %%
### Data Comp. Day2  PMT1 (Anode Window)
binss=np.linspace(0,14500,50)
plt.figure(figsize=(12,8),dpi=300)
plt.title("Anode Window S2 Light Yield Comparison_")
plt.ylabel("Number of Events")
plt.xlabel("NPE")

plt.hist(Day2_PMT1_GainIL,bins=binss,density=True,stacked=True,label="After Purification",color="b",alpha=0.3)
#plt.hist(Result["AnodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) With Loss",alpha=0.3)
#plt.hist(Result["AnodeBetaPEs_G4"],bins=binss ,density=True,stacked=True,label="Bi210 (GEANT4)With Loss",alpha=0.3)
#plt.hist(ResultWithNoTransmission["AnodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4)",alpha=0.3)
#plt.hist(ResultWithNoTransmission["AnodeBetaPEs_G4"],bins=binss ,density=True,stacked=True,label="Bi210 (GEANT4)",alpha=0.3)
plt.hist(Result_172["AnodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) 172nm",alpha=0.3)
plt.hist(Result_170["AnodeAlphaPEs_G4"],bins=binss ,density=True,stacked=True,label="Po210 (GEANT4) 170nm",alpha=0.3)



#plt.hist(Result["SolidAngle_AnodeWindowBetas"],bins=binss ,density=True,stacked=True,label="Bi210 (SolidAngle)",alpha=0.3,color="k")
#plt.hist(Result["SolidAngle_AnodeWindowAlphas"],bins=binss ,density=True,stacked=True,label="Po210 (SolidAngle)",alpha=0.3,color="y")
plt.legend() 
#plt.savefig("/home/ilker/Desktop/CRAB_Pictures/PMT1_S2_Light_Yield_Comp.jpeg")

plt.show()

# %%
SimG4_Anode=Fit(Result["AnodeAlphaPEs_G4"],np.linspace(0,15000,60),3000,False)
SimSolidAngle_Anode=Fit(Result["SolidAngle_AnodeWindowAlphas"],np.linspace(0,15000,60),3000,False)
Data_Anode=Fit(Day2_PMT1_GainIL,np.linspace(0,15000,60),3000,False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 SimG4_Anode=Fit(Result["AnodeAlphaPEs_G4"],np.linspace(0,15000,60),3000,False)
#       2 SimSolidAngle_Anode=Fit(Result["SolidAngle_AnodeWindowAlphas"],np.linspace(0,15000,60),3000,False)
#       3 Data_Anode=Fit(Day2_PMT1_GainIL,np.linspace(0,15000,60),3000,False)
#
# NameError: name 'Result' is not defined

# %%
SimG4_Cathode=Fit(Result["CathodeAlphaPEs_G4"],np.linspace(0,3000,60),1200,False)
SimSolidAngle_Cathode=Fit(Result["SolidAngle_CathodeWindowAlphas"],np.linspace(0,3000,60),1200,False)

Data_Cathode=Fit(Day2_PMT3_GainIL,np.linspace(0,3000,60),1500,False)

# %%
### Simulation Light Yields
## Sim


ysim=np.array([SimG4_Cathode[1],SimG4_Anode[1]])
#ysimerr=[np.std(alpha_CathodeWindow_G4Filtered)/np.sqrt(len(alpha_CathodeWindow_G4Filtered)),np.std(alpha_AnodeWindow_G4Filtered)/np.sqrt(len(alpha_AnodeWindow_G4Filtered))]

## SolidAngle sim
ysolid=np.array([SimSolidAngle_Cathode[1],SimSolidAngle_Anode[1]])
#ysoliderr=[np.std(SolidAngle_AlphaCathodeWindow_G4Filtered)/np.sqrt(len(SolidAngle_AlphaCathodeWindow_G4Filtered)),np.std(SolidAngle_AlphaAnodeWindow_G4Filtered)/np.sqrt(len(SolidAngle_AlphaAnodeWindow_G4Filtered))]
yData=np.array([Data_Cathode[1],Data_Anode[1]])

# %%
#### Error Calculation
AnodeDataError={}
CathodeDataError={}

## Calculating Error on  betweem data,solid Angle and GEANT4
AnodeMeans=np.array([yData[1],ysim[1],ysolid[1]])
CathodeMeans=np.array([yData[0],ysim[0],ysolid[0]])

print(f"Anode Means {AnodeMeans}")
print(f"Cathode Means {CathodeMeans}")
AnodeDataError["Data"]=np.std(AnodeMeans)/np.sqrt(len(AnodeMeans))
CathodeDataError["Data"]=np.std(CathodeMeans)/np.sqrt(len(CathodeMeans))


## Calculating Error on between GEANT4 to DATA
AnodeMeans=np.array([yData[1],ysim[1]])
CathodeMeans=np.array([yData[0],ysim[0]])

AnodeDataError["GEANT4"]=np.std(AnodeMeans)/np.sqrt(len(AnodeMeans))
CathodeDataError["GEANT4"]=np.std(CathodeMeans)/np.sqrt(len(CathodeMeans))

## Calculating Error on between Solid Angle to DATA
AnodeMeans=np.array([yData[1],ysolid[1]])
CathodeMeans=np.array([yData[0],ysolid[0]])

AnodeDataError["SolidAngle"]=np.std(AnodeMeans)/np.sqrt(len(AnodeMeans))
CathodeDataError["SolidAngle"]=np.std(CathodeMeans)/np.sqrt(len(CathodeMeans))


### 
ydataerr=np.array([CathodeDataError["Data"],AnodeDataError["Data"]])
ysimerr=np.array([CathodeDataError["GEANT4"],AnodeDataError["GEANT4"]])
ysoliderr=np.array([CathodeDataError["SolidAngle"],AnodeDataError["SolidAngle"]])

# %% [raw]
# plt.rcParams["figure.figsize"] = [12, 8]
# plt.rcParams["figure.autolayout"] = True
#
#
#
# ySimPerror=(abs(100*(ysolid-ysim)/ysim))
#
# ySolidPerror=abs(100*(ysim-yData)/yData)
#
#
# print(f" Percent Error on G4 and Solid Angle -> {ySimPerror}")
# print(f" Percent Error on G4 and Data -> {ySolidPerror}")
# # assign data
# mydata = [
#     ["Data",yData[0],ydataerr[0],yData[1],ydataerr[1]],
#     ["GEANT4", ysim[0],ysimerr[0], ysim[1],ysimerr[1]],
#     ["Solid Angle", ysolid[0],ysoliderr[0], ysolid[1],ysoliderr[1]]
# ]
#
# # create header
# head = ["Method", "CathodeWindow (NPE)","Error (NPE)","AnodeWindow (NPE)","Error (NPE)"]
#
# # display table
# print(tabulate(mydata, headers=head, tablefmt="grid"))
#
#
# print(f"\n Error in the Anode {AnodeDataError}")
# print(f" Error in the Cathode {CathodeDataError}")
#
#
#
# ind = np.arange(2) # the x locations for the groups
# width = 0.1 # the width of the bars
# shift=-0.1
# fig, ax = plt.subplots()
# rects1 = ax.bar(ind - width+shift, yData, width, yerr=[Data_Cathode[2],Data_Anode[2]], label='Data',color="green",linewidth=20)
# ax.plot(ind - width+shift,yData,  marker="D", linestyle="", alpha=0.8, color="r")
#
# rects2 = ax.bar(ind + width+shift, ysim, width, yerr=(ysim*0.3), label='GEANT4',color="royalblue",linewidth=20)
# ax.plot(ind + width+shift,ysim,  marker="D", linestyle="", alpha=0.8, color="r")
#
# rects3 = ax.bar(ind + 2*width+shift, ysolid, width, label='Geometric',color="dodgerblue",linewidth=20)
# #ax.plot(ind + 2*width+shift,ysolid,  marker="D", linestyle="", alpha=0.8, color="r")
#
# ax.set_ylabel('NPE')
# ax.set_xlabel('PMTs')
# #ax.set_title('PMTs')
# ax.set_xticks(ind)
# ax.set_xticklabels(('Cathode Window', 'Anode Window'))
# ax.legend(loc="upper left")
#
#
# plt.show()

# %%
mydata = [
    ["Data",yData[0],ydataerr[0],yData[1],ydataerr[1]],
    ["GEANT4", ysim[0],ysimerr[0], ysim[1],ysimerr[1]],
    ["Solid Angle", ysolid[0],ysoliderr[0], ysolid[1],ysoliderr[1]]
]

# %%
MData=yData/5.3
MDataErr=(yData/5.3)*0.3

MG4=ysim/5.3
MG4Err=(ysim/5.3)*0.3
MSolid=(ysolid/5.3)
MSolidErr=(ysim/5.3)*0.3


 
# assign data
mydata = [
    ["Data", MData[0],MDataErr[0], MData[1],MDataErr[1]],
    ["GEANT4", MG4[0],MG4Err[0], MG4[1],MG4Err[1]],
    ["Solid Angle", MSolid[0],MSolidErr[0], MSolid[1],MSolidErr[1]]


]
 
# create header
head = ["Method", "CathodeWindow (NPE/MeV)","Error (NPE/MeV)","AnodeWindow (NPE/MeV)","Error (NPE/MeV)"]
 
# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))

# %% [raw]
# #EnergyCut=Maxbeta_AnodeWindow_PE/(Point_SolidAngle(0.5,14)*647*0.2)
#
# #print(f"Maxbeta--> {Maxbeta_AnodeWindow_PE}")
# #print(f"EnergyCut--> {EnergyCut}")
# #print(f"Max Alpha --> {np.max(Alphas)}")
# #print(f"Max Betas --> {np.max(Betas)}")
#
# #AlphaEs=(Alphas[Alphas>EnergyCut])*22 ## eV
#
#
# #ContAlphaE=np.mean(AlphaEs)
# #ContAlphaErr=np.std(AlphaEs)
#
# #ParticleEs=np.array([ContAlphaE,ContAlphaE])
#
# DataRatio=yData/5.3
#
#
#
# G4Mean=np.array([np.mean(SolidAngle_AlphaCathodeWindow_G4Filtered),np.mean(SolidAngle_AlphaAnodeWindow_G4Filtered)])
# SimRatioSolid=ParticleEs/G4Mean
# #print(ErrorSolid)
#
#
#
# G4Mean=np.array([np.mean(alpha_CathodeWindow_G4Filtered),np.mean(alpha_AnodeWindow_G4Filtered)])
# SimRatioG4=ParticleEs/G4Mean
#
#
#
# ##converting eV/NPE to NPE/MeV
# dataval=(1/DataRatio)
# g4val=(1/SimRatioG4)*1e6
# solidval=(1/SimRatioSolid)*1e6
#
#
# print("\n--- Anode Window ---")
#
#
# print("\n---- For Data ---")
#
# print(f" Alphas(NPE/MeV) --> {round(dataval[1],2)} error --> {round(np.std([dataval[1],g4val[1],solidval[1]])/np.sqrt(3),2)}" )
#
# print("\n--- For GEANT4 ---")
# print(f" Alphas(NPE/MeV) --> {round(g4val[1],2)} error --> {round(np.std([dataval[1],g4val[1]])/np.sqrt(2),2)}" )
#
# print("\n--- For SolidAngle ---")
# print(f" Alphas(NPE/MeV) --> {round(solidval[1],2)} error --> {round(np.std([dataval[1],solidval[1]])/np.sqrt(2),2)}" )
#
#
# print("\n--- Cathode Window ---")
#
#
# print("\n---- For Data ---")
# print(f" Alphas(NPE/MeV) --> {round(dataval[0],2)} error --> {round(np.std([dataval[0],g4val[0],solidval[0]])/np.sqrt(3),2)}" )
#
# print("\n--- For GEANT4 ---")
# print(f" Alphas(NPE/MeV) --> {round(g4val[0],2)} error --> {round(np.std([dataval[0],g4val[0]])/np.sqrt(2),2)}" )
#
# print("\n--- For SolidAngle ---")
# print(f" Alphas(NPE/MeV) --> {round(solidval[0],2)} error --> {round(np.std([dataval[0],solidval[0]])/np.sqrt(2),2)}" )
#
#
#
# print(f"\nMax NPE Beta Anode --> {round(Maxbeta_AnodeWindow_PE,2)}")
# print(f"Max NPE Beta Cathode --> {round(MaxbetaPECathode,2)}")
#
#
#
# # Create two subplots and unpack the output array immediately
# f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)
# ax1.set_title("Anode Alphas Yield ")
# ax1.set_xlabel("NPE")
# ax1.set_ylabel("# of Events")
# binss=np.linspace(0,13000,50)
# ax1.hist(PMT1_AfterPurifaction_Alphas_DFiltered,bins=binss,stacked=True,density=True,label="DATA",alpha=0.5)
# ax1.hist(SolidAngle_AlphaAnodeWindow_G4Filtered,bins=binss,stacked=True,density=True,label="Solid Angle",alpha=0.5)
# ax1.hist(alpha_AnodeWindow_G4Filtered,bins=binss,stacked=True,density=True,label="GEANT4",alpha=0.5)
# ax1.legend()
#
# ax2.set_title("Cathode Alphas Yield ")
# ax2.set_xlabel("NPE")
# ax2.set_ylabel("# of Events")
# binss=np.linspace(0,3000,50)
# ax2.hist(PMT3_AfterPurifaction_Alphas_DFiltered,bins=binss,stacked=True,density=True,label="DATA",alpha=0.5)
# ax2.hist(SolidAngle_AlphaCathodeWindow_G4Filtered,bins=binss,stacked=True,density=True,label="Solid Angle",alpha=0.5)
# ax2.hist(alpha_CathodeWindow_G4Filtered,bins=binss,stacked=True,density=True,label="GEANT4",alpha=0.5)
# ax2.legend()

# %% [raw]
# AnodeAlphaPEs_G4=Result["AnodeAlphaPEs_G4"]
# AnodeBetaPEs_G4=Result["AnodeBetaPEs_G4"]
#
# print("----- Anode Window S2 Simulation -----")
# print(f" Alpha Mean --> {np.mean(AnodeAlphaPEs_G4)} and STD -->{np.std(AnodeAlphaPEs_G4)}")
# print(f" Alpha Max --> {np.max(AnodeAlphaPEs_G4)}")
# print(f" Alpha Min --> {np.min(AnodeAlphaPEs_G4)}")
#
# print("----- Betas -----")
# print(f" Betas Mean --> {np.mean(AnodeBetaPEs_G4)} and STD -->{np.std(AnodeBetaPEs_G4)}")
# print(f" Betas Max --> {np.max(AnodeBetaPEs_G4)}")
# print(f" Betas Min --> {np.min(AnodeBetaPEs_G4)}")
#
#
# Maxbeta_AnodeWindow_PE=np.max(AnodeBetaPEs_G4)
#
#
# ########### Data #################
#
#
# print("----- After Purifaction -----")
# print("---- Alphas ----")
# print(f" Mean --> {np.mean(Day2_PMT1_GainIL[Day2_PMT1_GainIL>Maxbeta_AnodeWindow_PE])} and STD -->{np.std(Day2_PMT1_GainIL[Day2_PMT1_GainIL>Maxbeta_AnodeWindow_PE])}")
# print(f" Max --> {np.max(Day2_PMT1_GainIL[Day2_PMT1_GainIL>Maxbeta_AnodeWindow_PE])}")
# print(f" Min --> {np.min(Day2_PMT1_GainIL[Day2_PMT1_GainIL>Maxbeta_AnodeWindow_PE])}")
#
#
# print("---- Betas ----")
# print(f" Mean --> {np.mean(Day2_PMT1_GainIL[Day2_PMT1_GainIL<=Maxbeta_AnodeWindow_PE])} and STD -->{np.std(Day2_PMT1_GainIL>[Day2_PMT1_GainIL<=Maxbeta_AnodeWindow_PE])}")
# print(f" Max --> {np.max(Day2_PMT1_GainIL[Day2_PMT1_GainIL<=Maxbeta_AnodeWindow_PE])}")
# print(f" Min --> {np.min(Day2_PMT1_GainIL[Day2_PMT1_GainIL<=Maxbeta_AnodeWindow_PE])}")
#
#
#
# #### Condition for seperating Alphas from betas in data ####
#
# PMT1_AfterPurifaction_Alphas_DFiltered=Day2_PMT1_GainIL[Day2_PMT1_GainIL>Maxbeta_AnodeWindow_PE]
# PMT1_AfterPurifaction_Betas_DFiltered=Day2_PMT1_GainIL[Day2_PMT1_GainIL<=Maxbeta_AnodeWindow_PE]
#
# alpha_AnodeWindow_G4Filtered=AnodeAlphaPEs_G4[AnodeAlphaPEs_G4>Maxbeta_AnodeWindow_PE]
#
# SolidAngle_AlphaAnodeWindow_G4Filtered=SolidAngle_AnodeWindowAlphas[SolidAngle_AnodeWindowAlphas>Maxbeta_AnodeWindow_PE]
#
#
# print("---- Seperated Alphas ----")
# print(f"Mean --> {np.mean(PMT1_AfterPurifaction_Alphas_DFiltered)} and STD -->{np.std(PMT1_AfterPurifaction_Alphas_DFiltered)}")
# print(f"Mean --> {np.mean(PMT1_AfterPurifaction_Betas_DFiltered)} and STD -->{np.std(PMT1_AfterPurifaction_Betas_DFiltered)}")

# %% [markdown]
# Since two different centeral wavelengths of scintilation photons reported in literature at 10 bar Xenon. We have compared 170~nm \cite{170nm} and 172~nm \cite{172nm} in GEANT4. According to digitized values of QEs from the PMT manual \cite{Hamamatsu}, there is 0.6% difference in QEs and also there is 1% difference in MgF2 transmission efficiencies \cite{ANL} between these wavelengths. We have simulated seperate 5.3 MeV alphas events in 9.7 bar Xenon with Xenon electroluminesence emmision spectrum peaking at 170 nm and 172 nm. We have obtained number of PEs in the both windows by applying corresponding QEs and MgF2 transmission efficiencies for each wavelength. The mean PE are obtained by a gaussian fit and percent difference of the means are calculated for each window between 170nm and 172nm distributions. The error on percent differences are estimated from standard deviations of the distributions. Results indicate that there is 1.8 $\pm{0.1}$ \% at Anode Windows while 1.4 $\pm{0.1}$ \% at Cathode Window. According to these results, the differences are small. Therefore, we have decided to use 172 nm in our simulations.
